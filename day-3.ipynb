# %% [markdown]
# ## 1. Recursive Factorial

# %%
def fact(num):
    if num==0:
        return 1
    return num*fact(num-1)

num = int(input("Enter a num: "))
print("Factorial is: ", fact(num))
# Out:
# Enter a num:  5
# Factorial is:  120

# %% [markdown]
# ## 2. Palindrome Linked List

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def middleNode(self, head: ListNode) -> ListNode:
        fast = slow = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        return slow

    def reverseList(self, head: ListNode) -> ListNode:
        prev = None
        while head:
            next_node = head.next
            head.next = prev
            prev = head
            head = next_node
        return prev

    def isPalindrome(self, head: ListNode) -> bool:
        middle = self.middleNode(head)
        mid_reverse = self.reverseList(middle)

        while head and mid_reverse:
            if head.val != mid_reverse.val:
                return False
            head = head.next
            mid_reverse = mid_reverse.next

        return True


def create_linked_list(arr):
    if not arr:
        return None
    head = ListNode(arr[0])
    current = head
    for value in arr[1:]:
        current.next = ListNode(value)
        current = current.next
    return head

# Main function to test the Solution class
def main():
    solution = Solution()

    # Test case 1
    head1 = create_linked_list([1, 2, 3, 2, 1])
    if solution.isPalindrome(head1):
        print("The linked list is a palindrome.")
    else:
        print("The linked list is not a palindrome.")

if __name__ == "__main__":
    main()
# Out:
# The linked list is a palindrome.

# %% [markdown]
# > inspired by [GitHub](https://github.com/MahraibFatima/LeeJam-codes/blob/main/234-palindrome-linked-list/palindrome-linked-list.cpp)

# %% [markdown]
# ## 3. Merge Sorted Arrays

# %%
def merge_sorted_arrays(arr1, arr2):
    merged_array = []
    i, j = 0, 0

    while i < len(arr1) and j < len(arr2):
        if arr1[i] < arr2[j]:
            merged_array.append(arr1[i])
            i += 1
        else:
            merged_array.append(arr2[j])
            j += 1

    while i < len(arr1):
        merged_array.append(arr1[i])
        i += 1

    while j < len(arr2):
        merged_array.append(arr2[j])
        j += 1

    return merged_array


def main():
    arr1 = [1, 3, 5]
    arr2 = [2, 4, 6]
    result = merge_sorted_arrays(arr1, arr2)
    print(result)  

if __name__ == "__main__":
    main()
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Merging Process:
#    Use a while loop to traverse both arrays until one of the arrays is completely processed.
#    Compare the current elements of arr1 and arr2:
#  - If arr1[i] is smaller, append it to the merged_array and increment i.
#  - Otherwise, append arr2[j] to the merged_array and increment j.

# %% [markdown]
# ## 4. Binary Search Tree

# %% [markdown]
# ---pending

# %% [markdown]
# ## 5. Longest Palindromic Substring

# %%
def longest_palindromic_substring(s: str) -> str:
    if not s:
        return ""
    
    def expand_around_center(s: str, left: int, right: int) -> str:
        while left >= 0 and right < len(s) and s[left] == s[right]:
            left -= 1
            right += 1
        return s[left + 1:right]
    
    longest = ""
    for i in range(len(s)):
        palindrome1 = expand_around_center(s, i, i)
        if len(palindrome1) > len(longest):
            longest = palindrome1
        
        palindrome2 = expand_around_center(s, i, i + 1)
        if len(palindrome2) > len(longest):
            longest = palindrome2
    
    return longest


print(longest_palindromic_substring("bababd"))  
print(longest_palindromic_substring("cbbd"))
# Out:
# babab
# bb

# %% [markdown]
# ## 6. Merge Intervals

# %% [markdown]
# ---pending

# %% [markdown]
# ## 7. Maximum Subarray

# %% [markdown]
# ---pending

# %% [markdown]
# ## Reverse Linked List

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        pre = None
        next = None
        while head is not None:
            next = head.next
            head.next = pre
            pre = head
            head = next
        return pre
def print_list(head: ListNode):
    while head:
        print(head.val, end=" -> ")
        head = head.next
    print("None")

# Create a linked list 1 -> 2 -> 3 -> 4 -> 5 -> None
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))

print("Original List:")
print_list(head)

solution = Solution()
reversed_head = solution.reverseList(head)

print("Reversed List:")
print_list(reversed_head)
# Out:
# Original List:
# 1 -> 2 -> 3 -> 4 -> 5 -> None
# Reversed List:
# 5 -> 4 -> 3 -> 2 -> 1 -> None

# %% [markdown]
# inspired by [Github](https://github.com/MahraibFatima/LeeJam-codes/blob/main/206-reverse-linked-list/reverse-linked-list.cpp)

# %% [markdown]
# ## 9. Minimum Edit Distance

# %% [markdown]
# ---pending

# %% [markdown]
# ## 10. Boggle Game

# %% [markdown]
# ---pending
